# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from src.lib.EMA.Builder import Create

# %%
np.random.seed(1997)

# %%
X = np.cumprod(1 + np.random.randn(300) * 0.01)

# %%
ema4 = Create(pd.Series(X),4)
ema8 =  Create(pd.Series(X),8)

# %%
plt.figure(figsize=(30, 10), dpi=80)
plt.xlim(0, len(X))
plt.ylim(X.min()*0.99, X.max()*1.01)
plt.plot(np.arange(len(X)), X, 'k:', alpha=0.5)
plt.plot(ema4, "g-")
plt.plot(ema8, "r-")
