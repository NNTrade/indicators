# %% [markdown]
# # Init

# %%
from pandas_data_reader_service_core.modules.finam.search_service import Search, Market
from pandas_data_reader_service_core.modules.finam.stock_info import FinamStockInfo
from pandas_data_reader_service_core.service import PandasDataReaderService as pdrs, StockInfo, TimeFrame

from datetime import date

import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

# %%
stock = "EURUSD"
market = Market.CURRENCIES_WORLD

date_from = date(2020,1,7)
date_till = date(2021,7,14)
tf = TimeFrame.DAILY

# %% [markdown]
# # Load data

# %%
stock_list = Search.by_code(stock, market)
stock_list
# Out:
#        name    code  market
# id
# 83  Eur/Usd  EURUSD       5

# %%
stock_info = StockInfo.init_for_Finam(FinamStockInfo(stock_list.index[0]))
print(stock_info)
# Out:
# Source StockSource.Finam source StockInfo Market 5 code EURUSD index 83

# %%
data_df = pdrs().get(stock=stock_info,  date_from=date_from,date_to=date_till,time_frame=tf,short_col_name=True)
data_df
# Out:
#                   O        H        L        C        V
# DT
# 2020-01-07  1.11954  1.11971  1.11320  1.11540  1610661
# 2020-01-08  1.11541  1.11682  1.11000  1.11127  2131727
# 2020-01-09  1.11129  1.11204  1.10920  1.11092  1423627
# 2020-01-10  1.11093  1.11292  1.10840  1.11200  1299383
# 2020-01-12  1.11175  1.11225  1.11108  1.11160    34731
# ...             ...      ...      ...      ...      ...
# 2021-07-11  1.18500  1.18785  1.18500  1.18724    43118
# 2021-07-12  1.18724  1.18802  1.18340  1.18626   776966
# 2021-07-13  1.18619  1.18751  1.17700  1.17740   925275
# 2021-07-14  1.17748  1.18388  1.17700  1.18328   878359
# 2021-07-15  1.18328  1.18506  1.17940  1.18106   898130
#
# [477 rows x 5 columns]

# %%
fig = go.Figure(data=[go.Candlestick(x=data_df.index,
                open=data_df['O'],
                high=data_df['H'],
                low=data_df['L'],
                close=data_df['C'])])
fig.update_yaxes(fixedrange=False)
fig.update_layout(height=1000)
fig.show()
# Out:
# <div>                            <div id="e283ade6-f4e3-45d7-8c96-5852460a2193" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e283ade6-f4e3-45d7-8c96-5852460a2193")) {                    Plotly.newPlot(                        "e283ade6-f4e3-45d7-8c96-5852460a2193",                        [{"close":[1.1154,1.11127,1.11092,1.112,1.1116,1.11343,1.11275,1.11522,1.11369,1.1088,1.10945,1.10962,1.10851,1.10957,1.10551,1.10251,1.10241,1.10188,1.10217,1.10137,1.10284,1.10917,1.10891,1.1061,1.10446,1.10004,1.09807,1.0944,1.0949,1.09101,1.09189,1.08747,1.08403,1.08301,1.08403,1.0835,1.07947,1.08096,1.07875,1.08471,1.08385,1.08487,1.08795,1.08862,1.09963,1.10289,1.10517,1.11443,1.11765,1.1138,1.12225,1.1285,1.13868,1.13991,1.13136,1.12605,1.11822,1.1105,1.11554,1.11636,1.10161,1.0943,1.06541,1.06929,1.06883,1.07632,1.07978,1.0888,1.10469,1.114,1.11361,1.10292,1.10263,1.095,1.08456,1.08124,
.19493,1.19254,1.19016,1.19826,1.19174,1.1904,1.18835,1.1932,1.18396,1.18119,1.17747,1.17928,1.17874,1.1767,1.17232,1.17268,1.17772,1.1761,1.17666,1.18167,1.18736,1.18724,1.19145,1.19008,1.18953,1.19118,1.19537,1.19828,1.19692,1.19823,1.19686,1.20424,1.20324,1.20371,1.20139,1.20965,1.20891,1.20795,1.20891,1.21347,1.2123,1.2019,1.20269,1.2058,1.20137,1.20072,1.20648,1.21625,1.21704,1.21397,1.21442,1.20774,1.20765,1.21451,1.21497,1.21563,1.22223,1.21704,1.22242,1.2178,1.21807,1.22139,1.2247,1.2192,1.21925,1.2189,1.2189,1.22323,1.22166,1.22092,1.21298,1.2164,1.21663,1.2189,1.21716,1.21783, ...

# %% [markdown]
# # Find Rules

# %% [markdown]
# ## Support functions

# %%
from __future__ import annotations

class candle_chart:
    def __init__(self,df: pd.DataFrame) -> None:
        self.fig = go.Figure(data=[go.Candlestick(x=df.index,
            open= df['O'],
            high= df['H'],
            low=  df['L'],
            close=df['C'])])
        self.fig.update_yaxes(fixedrange=False)
        self.fig.update_layout(height=1000)
        self.max = df.H.max()
        self.min = df.L.min()
        pass

    def add_marker(self, marker_candle:pd.Series)->candle_chart:
        self.fig.add_shape(type="line",
            x0=marker_candle.name, x1=marker_candle.name, y0=self.min, y1=marker_candle["L"],
            line=dict(
                color="MediumPurple",
                width=4,
                dash="dot",
            )
        )

        self.fig.add_shape(type="line",
            x0=marker_candle.name, x1=marker_candle.name, y0=marker_candle["H"], y1=self.max,
            line=dict(
                color="MediumPurple",
                width=4,
                dash="dot",
            )
        )
        return self
    
    def add_wave_from_point(self, start_point: point, end_point:point, main_wave: bool = True)->candle_chart:
        return self.add_wave(start_point.dt,start_point.value,end_point.dt,end_point.value,main_wave)
        
    def add_wave(self, start_dt:pd.Timestamp, start_value:float, end_dt:pd.Timestamp, end_value:float, main_wave: bool = True)->candle_chart:
        if end_value > start_value:
            color = "Green"
        else:
            color = "Red"
        if main_wave:
            dash = "solid"
        else:
            dash = "dashdot"
        self.fig.add_shape(type="line",
            x0=start_dt, x1=end_dt, y0=start_value, y1=end_value,
            line=dict(
                color=color,
                width=2,
                dash=dash,
            )
        )
        return self
    def show(self):
        self.fig.show()

class point:
    def __init__(self,dt:pd.Timestamp, value:float) -> None:
        self.dt = dt
        self.value = value
        pass
    @staticmethod
    def from_candle(candle:pd.Series, value_name:str)->point:
        return point(candle.name, candle[value_name])

def height(point_start:point, point_end:point ):
    return point_end.value - point_start.value

def check_rule(rule_name: str, answer:bool):
    if not answer:
        raise Exception(f"Rule {rule_name} doesn't passed")
    else:
        print(f"Rule {rule_name}: checked")

# %%
zoom = (pd.Timestamp(year=2020, month=5,day=1),  pd.Timestamp(year=2021,month=2,day=1))
zoom_df = data_df.loc[[dt for dt in data_df.index if (dt >= zoom[0]) & (dt <= zoom[1])]]

# %% [markdown]
# ## Wave1

# %% [markdown]
# ### Define wave

# %% [markdown]
# #### Define Start Wave 1 SW1

# %%
SW1_dt = pd.Timestamp(year=2020,month=5,day=14)
SW1_dt
# Out:
# Timestamp('2020-05-14 00:00:00')

# %%
SW1_candle = data_df.loc[SW1_dt]
SW1_candle
# Out:
# O    1.082110e+00
# H    1.082400e+00
# L    1.077300e+00
# C    1.080560e+00
# V    1.696707e+06
# Name: 2020-05-14 00:00:00, dtype: float64

# %% [markdown]
# #### Define End Wave 1 EW1

# %%
EW1_dt = pd.Timestamp(year=2020,month=6,day=10)
EW1_dt
# Out:
# Timestamp('2020-06-10 00:00:00')

# %%
EW1_candle = data_df.loc[EW1_dt]
EW1_candle
# Out:
# O    1.133160e+00
# H    1.142250e+00
# L    1.132050e+00
# C    1.136650e+00
# V    2.821155e+06
# Name: 2020-06-10 00:00:00, dtype: float64

# %% [markdown]
# #### Define range wave 1 RW1

# %%
RW1 = zoom_df.loc[[dt for dt in zoom_df.index if (dt >= SW1_dt) & (dt <= EW1_dt)]]
RW1.head()
# Out:
#                   O        H        L        C        V
# DT
# 2020-05-14  1.08211  1.08240  1.07730  1.08056  1696707
# 2020-05-15  1.08049  1.08512  1.07875  1.08179  1528162
# 2020-05-17  1.08380  1.08380  1.08060  1.08185    72782
# 2020-05-18  1.08187  1.09270  1.07980  1.09137  1630550
# 2020-05-19  1.09139  1.09761  1.09006  1.09260  1629331

# %% [markdown]
# #### Define values

# %%
SW1_point = point.from_candle(SW1_candle,"L")
EW1_point = point.from_candle(EW1_candle,"H")

# %%
candle_chart(zoom_df).add_marker(SW1_candle).add_marker(EW1_candle).add_wave_from_point(SW1_point,EW1_point).show()
# Out:
# <div>                            <div id="437ba7f6-9886-4aef-a9eb-bbbab2609f93" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("437ba7f6-9886-4aef-a9eb-bbbab2609f93")) {                    Plotly.newPlot(                        "437ba7f6-9886-4aef-a9eb-bbbab2609f93",                        [{"close":[1.09798,1.09608,1.09023,1.08383,1.07978,1.08348,1.08379,1.08376,1.08081,1.08453,1.08207,1.08056,1.08179,1.08185,1.09137,1.0926,1.09789,1.0949,1.09,1.09077,1.09014,1.0978,1.10164,1.10778,1.11069,1.1115,1.1125,1.1184,1.12336,1.13353,1.12873,1.13152,1.1303,1.1331,1.13665,1.12865,1.12601,1.12514,1.13373,1.12631,1.12416,1.12072,1.1176,1.11764,1.12778,1.13124,1.12497,1.12163,1.12176,1.12216,1.12466,1.1233,1.125,1.12372,1.12464,1.12465,1.13115,1.12736,1.13369,1.12871,1.12973,1.13086,1.13438,1.1408,1.14168,1.13878,1.14253,1.14412,1.14549,1.15341,1.15636,1.15945,1.1656,1.16487,1.17682,1.1718,1.17807,1.18717,1.1771,1.17802,1.17603,1.18133,1.1872,1.18745,1.1787,1.1781,1.17351,1.17347,1.17938,1.18153,1.18408,1.18517,1.18745,1.19462,
1.1865,1.18599,1.18507,1.18388,1.1788,1.17588,1.17043,1.16512,1.1656,1.17641,1.1771,1.18598,1.1891,1.1895,1.19201,1.18433,1.18327,1.18232,1.18375,1.18489,1.1869,1.1894,1.18911,1.18826,1.18908,1.18661,1.19061,1.1898,1.19297,1.19409,1.19641,1.19739,1.20033,1.20767,1.21185,1.21746,1.21775,1.21331,1.21663,1.2134,1.21475,1.2159,1.2163,1.21435,1.21768,1.21689,1.22123,1.22728,1.22688,1.2252,1.22531,1.22571,1.2221,1.22157,1.2205,1.22073,1.22504,1.22753,1.23101,1.2 ...

# %% [markdown]
# ### Rules

# %%
check_rule("End wave 1 > start wave 1", EW1_point.value > SW1_point.value) 
check_rule("EW1 is max on range W1", (RW1[["H","L"]] < EW1_candle.H).any(axis=1).any())
# Out:
# Rule End wave 1 > start wave 1: checked
# Rule EW1 is max on range W1: checked

# %% [markdown]
# ## Wave 2

# %% [markdown]
# ### Define wave

# %% [markdown]
# #### Define Start Wave 2 SW2

# %%
SW2_dt = EW1_dt
SW2_candle = zoom_df.loc[SW2_dt]
SW2_candle
# Out:
# O    1.133160e+00
# H    1.142250e+00
# L    1.132050e+00
# C    1.136650e+00
# V    2.821155e+06
# Name: 2020-06-10 00:00:00, dtype: float64

# %% [markdown]
# #### Define End Wave 2 SW2

# %%
EW2_dt = pd.Timestamp(year=2020,month=6,day=19)
EW2_candle = zoom_df.loc[EW2_dt]
EW2_candle
# Out:
# O    1.120720e+00
# H    1.125440e+00
# L    1.116600e+00
# C    1.117600e+00
# V    2.234771e+06
# Name: 2020-06-19 00:00:00, dtype: float64

# %% [markdown]
# #### Define range wave 2 RW2

# %%
RW2 = zoom_df.loc[[dt for dt in zoom_df.index if (dt >= SW2_dt) & (dt <= EW2_dt)]]
RW2.head()
# Out:
#                   O        H        L        C        V
# DT
# 2020-06-10  1.13316  1.14225  1.13205  1.13665  2821155
# 2020-06-11  1.13667  1.14037  1.12850  1.12865  3285237
# 2020-06-12  1.12876  1.13406  1.12110  1.12601  2897746
# 2020-06-14  1.12480  1.12587  1.12250  1.12514   159708
# 2020-06-15  1.12514  1.13384  1.12250  1.13373  3251692

# %% [markdown]
# #### Define values

# %%
SW2_point = point.from_candle(SW2_candle,"H")
EW2_point = point.from_candle(EW2_candle,"L")

# %%
candle_chart(zoom_df).add_marker(SW1_candle).add_marker(EW1_candle).add_wave_from_point(SW1_point,SW2_point)\
                     .add_marker(SW2_candle).add_marker(EW2_candle).add_wave_from_point(SW2_point,EW2_point,main_wave=False)\
                     .show()
# Out:
# <div>                            <div id="92588f2a-c18b-429c-bbef-aabf29f263ed" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
.14437,1.14457,1.14677,1.15423,1.16015,1.16272,1.16581,1.1656,1.17815,1.17737,1.18064,1.18764,1.19088,1.17968,1.17889,1.1815,1.19049,1.19162,1.1882,1.1792,1.18007,1.1808,1.18171,1.18642,1.18504,1.1853,1.1881,1.19656,1.19527,1.18711,1.18829,1.18068,1.18496,1.18439,1.18406,1.19019,1.19197,1.19202,1.19661,1.20114,1.19241,1.18646,1.18654,1.18506,1.18487,1.18276,1.18342,1.19175,1.18742,1.18475,1.1888,1.19005,1.18826,1.18561,1.18705,1.185,1.18719,1.17716,1.1719,1.1687,1.16851,1.16379,1.168,1.17458,1.1755,1.17696,1.17446,1.17201,1.17975,1.18077,1.1782,1.17818,1.1831,1.18232,1.18268,1.1814,1.1771,1.17578,1.17462,1.17229,1.17938,1.18408,1.18807,1.18669,1.1865,1.18599,1.18507,1.18388,1.1788,1.17588,1.17043,1.16512,1.1656,1.17641,1.1771,1.18598,1.1891,1.1895,1.19201,1.18433,1.18327,1.18232,1.18375,1.18489,1.1869,1.1894,1.18911,1.18826,1.18908,1.18661,1.19061,1.1898,1.19297,1.19409,1.19641,1.19739,1.20033,1.20767,1.21185,1.21746,1.21775,1.21331,1.21663,1.2134,1.21475,1.2159,1.2163,1.21435,1.21768,1.21689,1.22123,1.22728,1.22688,1.2252,1.22531,1.22571,1.2221,1.22157,1.2205,1.22073,1.22504,1.22753,1.23101,1.2 ...

# %% [markdown]
# ### Rules

# %%
check_rule("End wave 2 < start start wave 2",EW2_point.value < SW2_point.value)
check_rule("EW2 is min on RW2", (RW2[["H","L"]] > EW2_candle.L).any(axis=1).any())
check_rule("End wave 2 > Start wave 1",EW2_point.value > SW1_point.value)
# Out:
# Rule End wave 2 < start start wave 2: checked
# Rule EW2 is min on RW2: checked
# Rule End wave 2 > Start wave 1: checked

# %% [markdown]
# ## Wave 3

# %% [markdown]
# ### Define wave

# %% [markdown]
# #### Define Start (SW3)

# %%
SW3_dt = EW2_dt
SW3_candle = zoom_df.loc[SW3_dt]
SW3_candle
# Out:
# O    1.120720e+00
# H    1.125440e+00
# L    1.116600e+00
# C    1.117600e+00
# V    2.234771e+06
# Name: 2020-06-19 00:00:00, dtype: float64

# %% [markdown]
# #### Define End (EW3)

# %%
EW3_dt = pd.Timestamp(year=2020,month=9,day=1)
EW3_candle = zoom_df.loc[EW3_dt]
EW3_candle
# Out:
# O    1.193650e+00
# H    1.201140e+00
# L    1.190000e+00
# C    1.192230e+00
# V    1.983008e+06
# Name: 2020-09-01 00:00:00, dtype: float64

# %% [markdown]
# #### Define range (RW3)

# %%
RW3 = zoom_df.loc[[dt for dt in zoom_df.index if (dt >= SW3_dt) & (dt <= EW3_dt)]]
RW3.head()
# Out:
#                   O        H       L        C        V
# DT
# 2020-06-19  1.12072  1.12544  1.1166  1.11760  2234771
# 2020-06-21  1.11900  1.11940  1.1167  1.11764    93933
# 2020-06-22  1.11765  1.12810  1.1172  1.12778  1979244
# 2020-06-23  1.12776  1.13486  1.1231  1.13124  2482232
# 2020-06-24  1.13121  1.13258  1.1246  1.12497  2216060

# %% [markdown]
# #### Define vales

# %%
SW3_point = point.from_candle(SW3_candle,"L")
EW3_point = point.from_candle(EW3_candle,"H")
HW3 = EW3

# %%
candle_chart(zoom_df).add_marker(SW1_candle).add_marker(EW1_candle).add_wave_from_point(SW1_point,SW2_point)\
                     .add_marker(SW2_candle).add_marker(EW2_candle).add_wave_from_point(SW2_point,EW2_point,main_wave=False)\
                     .add_marker(SW3_candle).add_marker(EW3_candle).add_wave_from_point(SW3_point,EW3_point)\
                     .show()
# Out:
# <div>                            <div id="1fadbff9-9823-4c66-a416-0c4817533322" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fadbff9-9823-4c66-a416-0c4817533322")) {                    Plotly.newPlot(                        "1fadbff9-9823-4c66-a416-0c4817533322",                        [{"close":[1.09798,1.09608,1.09023,1.08383,1.07978,1.08348,1.08379,1.08376,1.08081,1.08453,1.08207,1.08056,1.08179,1.08185,1.09137,1.0926,1.09789,1.0949,1.09,1.09077,1.09014,1.0978,1.10164,1.10778,1.11069,1.1115,1.1125,1.1184,1.12336,1.13353,1.12873,1.13152,1.1303,1.1331,1.13665,1.12865,1.12601,1.12514,1.13373,1.12631,1.12416,1.12072,1.1176,1.11764,1.12778,1.13124,1.12497,1.12163,1.12176,1.12216,1.12466,1.1233,1.125,1.12372,1.12464,1.12465,1.13115,1.12736,1.13369,1.12871,1.12973,1.13086,1.13438,1.1408,1.14168,1.13878,1.14253,1.14412,1.14549,1.15341,1.15636,1.15945,1.1656,1.16487,1.17682,1.1718,1.17807,1.18717,1.1771,1.17802,1.17603,1.18133,1.1872,1.18745,1.1787,1.1781,1.17351,1.17347,1.17938,1.18153,1.18408,1.18517,1.18745,1.19462,1.18436,1.18696,1.17958,1.17973,1.17926,1.18339,1.18391,1.18204,1.19008,1.19172,1.19357,1.19223,1.18452,1.18407,1.18389,1.18342,1.18188,1.17665,1.18035,1.18231,1.18453,1.18405,1.18661,1.18411,1.18043,1.1847,1.1839,1.18456,1.17629,1.1704,1.16557,1.16736,1.163,1.16341,1.16761,1.17414,1.17232,1.1743,1.1716,1.17191,1.1788,1.1736,1.1765,1.17664,1.1826,1.1814,1.18127,1.1742,1.17443,1.17055,1.17158,1.1714,1.17682,1.18287,1.18507,1.1813,1.1859,1.18478,1.18089,1.178,1.17473,1.16781,1.16459,1.16412,1.16404,1.176,1.17319,1.18165,1.18745,1.18922,1.18231,1.18183,1.17792,1.1804,1.1832,1.18445,1.18583,1.18634,1.1845,1.18653,1.1855,1.18654,1.18421,1.1896,1.19164,1.191,1.1963,1.19715,1.1937,1.20697,1.2113,1.21445,1.212,1.212,1.2109,1.2109,1.20778,1.21424,1.2111,1.21322,1.21485,1.21543,1.21952,1.22607,1.2255,1.221,1.22